# %% [markdown]
# # SpikeInterface Processing Pipeline for OpenEphys Neuropixels 2 & raw Axona recordings
# ### Jake Swann, 2024
#
# ##### This is a notebook which takes a spreadsheet as input with information on NP2 OpenEphys recordings, and sorts all unsorted recordings in a loop. It will concatenate all recordings made for each animal on each unique day, and sort them all together, to be split apart afterwards
# ##### Each path in the spreadsheet should be to a folder containing all recordings in a given day with the file structure: `base_folder/rXXXX/YYYY-MM-DD/`. Trial names should match those in the spreadsheet.
# ##### Required spreadsheet columns are: `trial_name, path (animal and date parts only), probe_type ('NP2_openephys'), num_channels (384), include ('Y')`
# ##### The script loads them as a [SpikeInterface](https://github.com/SpikeInterface) object & attaches probe geometry, spike sorts using [Kilosort2 (Axona)/ Kilosort 4 (Neuropixels)](https://github.com/MouseLand/Kilosort), and allows curation of the output in the [phy](https://github.com/cortex-lab/phy/) template-gui
# ##### **N.B.** This requires a Python 3.8 environment with SpikeInterface v0.101+ installed
# ---

# %%
sheet_path = 'https://docs.google.com/spreadsheets/d/1_Xs5i-rHNTywV-WuQ8-TZliSjTxQCCqGWOD2AL_LIq0/edit#gid=0'
path_to_data = '/home/isabella/Documents/isabella/jake/recording_data/'
sorting_suffix = 'sorting_ks2_custom'
probe_to_sort = '5x12_buz'

################################################################################################################

import os
import numpy as np
import pandas as pd
import spikeinterface as si
from spelt.session_utils import gs_to_df
from spelt.np2_utils.np2_preprocessing import sort_np2
from spelt.axona_utils.axona_preprocessing import sort_axona
from spelt.sorting_utils.collect_sessions import collect_sessions

# Load & format Google sheet, collect trials and sessions
sheet = gs_to_df(sheet_path)
sheet['path'] = path_to_data + sheet['path']
sheet_inc = sheet[sheet['Include'] == 'Y']
sheet_inc = sheet_inc[sheet_inc['probe_type'] == probe_to_sort]
trial_list = sheet_inc['trial_name'].to_list()
session_list = np.unique([f"{i.split('_')[0]}_{i.split('_')[1]}" for i in trial_list])

# Collect recordings for concatenation and sorting
recording_list = collect_sessions(session_list, trial_list, sheet_inc, probe_to_sort)

# Concatenate over a single session and sort
for recording in recording_list:
	session = pd.DataFrame(recording)
	base_folder = session.iloc[0,2]
	probe_type = session.iloc[0,3]

	# Concatenate recordings
	recordings_concat = si.concatenate_recordings(session.iloc[:,0].to_list())
	print(f'Sorting {recordings_concat}')

	if probe_type == 'NP2_openephys':
		# Save concatenated recording to .dat
		if f'concat.dat' in os.listdir(base_folder):
			print(f'{base_folder}/concat.dat already exists, skipping concatenation')
		else:
			si.write_binary_recording(recordings_concat, f'{base_folder}/concat.dat')
			print(f'Concatenated recording saved to {base_folder}/concat.dat')
		# Sort concatenated recording
		sorting = sort_np2(recording = recordings_concat, 
				recording_name = session.iloc[0,1], 
				base_folder = session.iloc[0,2],
				sorting_suffix = sorting_suffix)
		
	elif probe_type == '5x12_buz':
		sorting = sort_axona(recording = recordings_concat, 
				recording_name = session.iloc[0,1], 
				base_folder = session.iloc[0,2],
				electrode_type = session.iloc[0,3],
				sorting_suffix = sorting_suffix)

	session.to_csv(f'{session.iloc[0,2]}/{session.iloc[0,1][:6]}_{sorting_suffix}/session.csv') #save session trial info to .csv
# Out:
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-03/230503_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-03/230503_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-04/230504_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-04/230504_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-04/230504_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-04/230504_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-04/230504_r1354_raw_t-maze_1
# /data/isabella/jake/ephys_analysis/spikeinterface/src/spikeinterface/core/base.py:1064: UserWarning: Versions are not the same. This might lead to compatibility errors. Using spikeinterface==0.95.0 is recommended
#   warnings.warn(
# /data/isabella/jake/ephys_analysis/spikeinterface/src/spikeinterface/core/binaryrecordingextractor.py:78: UserWarning: `num_chan` is to be deprecated in version 0.100, please use `num_channels` instead
#   warnings.warn("`num_chan` is to be deprecated in version 0.100, please use `num_channels` instead")
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-04/230504_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-05/230505_r1354_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_r1354_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_r1354_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_r1354_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_r1354_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_r1354_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_r1354_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_r1354_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,800,300 samples
#                        600.01s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28800300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_r1354_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_r1354_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,200,300 samples
#                        900.01s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43200300
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_r1364_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_r1398_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_r1398_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_r1398_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_r1398_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_r1398_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_r1398_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_r1399_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-30/230730_r1398_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-30/230730_r1398_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_r1399_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_r1399_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_r1399_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_r1399_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_r1399_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_r1399_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-31/230731_r1398_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-31/230731_r1398_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-31/230731_r1398_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-31/230731_r1398_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_r1399_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_r1398_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_r1399_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_t-maze_1
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_t-maze_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_r1398_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_r1399_raw_open-field_1
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_r1399_raw_open-field_1_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_r1399_raw_open-field_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_r1399_raw_open-field_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                        900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# 43203000
# Loading /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_r1399_raw_t-maze_2
# /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_r1399_raw_t-maze_2_preprocessed
# 5x12_buz recording loaded from previous preprocessing
#  BinaryFolderRecording: 64 channels - 48.0kHz - 1 segments - 28,803,000 samples
#                        600.06s (10.00 minutes) - int16 dtype - 3.43 GiB
# 28803000
# ...
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-06/230506_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 115,200,900 samples
#                              2,400.02s (40.00 minutes) - int16 dtype - 13.73 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-07/230507_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,001,200 samples
#                              3,000.03s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-08/230508_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,001,200 samples
#                              3,000.03s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-09/230509_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 115,200,900 samples
#                              2,400.02s (40.00 minutes) - int16 dtype - 13.73 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1354/2023-05-10/230510_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 115,212,000 samples
#                              2,400.25s (40.00 minutes) - int16 dtype - 13.73 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-07/230607_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 115,209,000 samples
#                              2,400.19s (40.00 minutes) - int16 dtype - 13.73 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-08/230608_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-09/230609_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-10/230610_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-11/230611_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-12/230612_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-13/230613_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-14/230614_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-15/230615_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-16/230616_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-17/230617_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-18/230618_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1364/2023-06-19/230619_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 100,809,000 samples
#                              2,100.19s (35.00 minutes) - int16 dtype - 12.02 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-29/230729_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-29/230729_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 43,203,000 samples
#                              900.06s (15.00 minutes) - int16 dtype - 5.15 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-30/230730_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 115,209,000 samples
#                              2,400.19s (40.00 minutes) - int16 dtype - 13.73 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-30/230730_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 72,006,000 samples
#                              1,500.12s (25.00 minutes) - int16 dtype - 8.58 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-07-31/230731_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-07-31/230731_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-01/230801_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-01/230801_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-02/230802_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 100,809,000 samples
#                              2,100.19s (35.00 minutes) - int16 dtype - 12.02 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-02/230802_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 100,809,000 samples
#                              2,100.19s (35.00 minutes) - int16 dtype - 12.02 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-03/230803_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 72,006,000 samples
#                              1,500.12s (25.00 minutes) - int16 dtype - 8.58 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1399/2023-08-03/230803_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 72,006,000 samples
#                              1,500.12s (25.00 minutes) - int16 dtype - 8.58 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-04/230804_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-05/230805_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-06/230806_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-07/230807_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-08/230808_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-09/230809_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-10/230810_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 72,006,000 samples
#                              1,500.12s (25.00 minutes) - int16 dtype - 8.58 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1398/2023-08-11/230811_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-24/231024_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-25/231025_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-25/231025_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-26/231026_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-26/231026_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-27/231027_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 129,612,000 samples
#                              2,700.25s (45.00 minutes) - int16 dtype - 15.45 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-27/231027_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-28/231028_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-28/231028_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-29/231029_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-29/231029_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-30/231030_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-30/231030_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-10-31/231031_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 102,825,000 samples
#                              2,142.19s (35.70 minutes) - int16 dtype - 12.26 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1432/2023-10-31/231031_sorting_ks2_custom
#
# Sorting ConcatenateSegmentRecording: 64 channels - 48.0kHz - 1 segments - 144,012,000 samples
#                              3,000.25s (50.00 minutes) - int16 dtype - 17.17 GiB
# Sorting loaded from file /home/isabella/Documents/isabella/jake/recording_data/r1428/2023-11-01/231101_sorting_ks2_custom

# %% [markdown]
# #### Unused Code

# %%
import spikeinterface as si
import spikeinterface.extractors as se
import spikeinterface.widgets as sw

recording_path = '/data/isabella/jake/recording_data/NP2 data/2024-03-15/test/2024-03-15_13-05-49'
sorting_path = '/data/isabella/jake/recording_data/NP2 data/2024-03-15/test/kilosort4'

recording = se.read_openephys(folder_path=recording_path, stream_id = '0')
sorting = se.read_phy(sorting_path, exclude_cluster_groups=['noise', 'mua'])


import spikeinterface.postprocessing as sp
sorting_analyzer = si.create_sorting_analyzer(sorting=sorting, recording=recording)
sorting_analyzer.compute('random_spikes')
sorting_analyzer.compute('waveforms')
sorting_analyzer.compute_one_extension('templates')
si.postprocessing.compute_template_metrics(sorting_analyzer)
unit_locations = sorting_analyzer.compute(input="unit_locations", method="monopolar_triangulation")

sw.plot_rasters(sorting, time_range=[0, 10])
# Out:
# ========================================
# Loading recording with SpikeInterface...
# number of samples: 18613123
# number of channels: 384
# numbef of segments: 1
# sampling rate: 30000.0
# dtype: int16
# ========================================
# Interpreting binary file as default dtype='int16'. If data was saved in a different format, specify `data_dtype`.
# Using GPU for PyTorch computations. Specify `device` to change this.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       3 settings = {'fs': 30000, 'n_chan_bin': 384}
#       5 wrapper = io.RecordingExtractorAsArray(recordings_concat)
# ----> 6 ops, st, clu, tF, Wall, similar_templates, is_ref, est_contam_rate = run_kilosort(
#       7     settings=settings, probe='NP2_kilosortChanMap.mat', filename='/home/isabella/Documents/isabella/jake/recording_data/r1503/2024-03-15/240315_sorting_ks4', file_object=wrapper)
#
# File /data/isabella/jake/ephys_analysis/Kilosort/kilosort/run_kilosort.py:127, in run_kilosort(settings, probe, probe_name, filename, data_dir, file_object, results_dir, data_dtype, do_CAR, invert_sign, device, progress_bar, save_extra_vars)
#     124 # NOTE: Also modifies settings in-place
#     125 filename, data_dir, results_dir, probe = \
#     126     set_files(settings, filename, probe, probe_name, data_dir, results_dir)
# --> 127 ops = initialize_ops(settings, probe, data_dtype, do_CAR, invert_sign, device)
#     129 # Set preprocessing and drift correction parameters
#     130 ops = compute_preprocessing(ops, device, tic0=tic0, file_object=file_object)
#
# File /data/isabella/jake/ephys_analysis/Kilosort/kilosort/run_kilosort.py:213, in initialize_ops(settings, probe, data_dtype, do_CAR, invert_sign, device)
#     211 ops['invert_sign'] = invert_sign
#     212 ops['NTbuff'] = ops['batch_size'] + 2 * ops['nt']
# --> 213 ops['Nchan'] = len(probe['chanMap'])
#     214 ops['n_chan_bin'] = settings['n_chan_bin']
#     215 ops['torch_device'] = str(device)
#
# TypeError: string indices must be integers
